# %% [markdown]
# ## 非配对推理测试，只用trainA_crop_gray做推理测试

# %%
# vq_dual_v1
# !python infer_new.py --name vq_dual_v1_xijing_5090d --model vq_test --netG vq_dual \
--preprocess_mode flexible \
--input_dir ./datasets/xijing_split/trainA_crop_gray \
--output_dir ./results/infer_new/xijing_trainACropGray_vqdualv1_AtoB_flexNoResize

# %%
# vq_dual_v0
# !python infer_new.py --name vq_dual_v0_xijing_5090d --model vq_test --netG vq_dual \
--preprocess_mode flexible \
--input_dir ./datasets/xijing_split/trainA_crop_gray \
--output_dir ./results/infer_new/xijing_trainACropGray_vqdualv0_AtoB_flexNoResize

# %%
# vq_resnet
# !python infer_new.py --name vq_resnet_v1_xijing_5090d --model test --netG vq_resnet \
--preprocess_mode flexible \
--input_dir ./datasets/xijing_split/trainA_crop_gray \
--output_dir ./results/infer_new/xijing_trainACropGray_vqresnet_flexNoResize

# %%
# vanilla CycleGAN
# !cd /root/exp/pytorch-CycleGAN-and-pix2pix && \
python infer_new.py --name vanilla_cyclegan_5090d --model test --netG resnet_9blocks \
--preprocess_mode flexible \
--input_dir ../datasets/xijing_split/trainA_crop_gray \
--output_dir ./results/infer_new/xijing_trainACropGray_vanillaCyclegan_flexNoResize

# %%
# 3090 realesrgan
#!python inference_realesrgan.py -n net_g_latest_train0.pth -i ./datasets/xijing_split/trainA_crop_gray -o ./results/xijing_trainACropGray_RealESRGAN -s 1 --suffix '' -g 0
# !rsync -avP 3090_1.lan:/root/Lecter/cyclegan-exp/comparative-exp/Real-ESRGAN/Real-ESRGAN/results/xijing_trainACropGray_RealESRGAN /root/exp/Real-ESRGAN/results/
